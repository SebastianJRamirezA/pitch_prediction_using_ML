# %% [markdown]
# # Next Pitch Prediction using Attention-based LSTMs

# %% [markdown]
# The next series of tests will be carried out using Attention-based LSTMs. Attention-based LSTMs implement the attention mechanism to focus on specific parts of the input sequence, which can be beneficial for time series data like pitch prediction.

# %% [markdown]
# ## Data loading and sequencing

# %%
import os
import tensorflow as tf
import keras_tuner

os.chdir('../..')
tf.keras.utils.set_random_seed(42)

# %% [markdown]
# The first step is to load the pitch data and sequence it into a format that can be used to train the LSTM. For this, the preprocessing utils developed earlier will be used.
#
# It is also necessary to split the data into training, validation and test sets. A 60-20-20 split will be done using Scikit Learn.

# %%
from utils import preprocessing
from sklearn.model_selection import train_test_split

X, y_pitch, y_vertical, y_horizontal = preprocessing.get_sequences(os.path.join('data', 'raw', 'wade_miley.csv'))

# Split the data into training, validation, and testing sets
X_train, X_temp, y_pitch_train, y_pitch_temp, y_vertical_train, y_vertical_temp, y_horizontal_train, y_horizontal_temp = train_test_split(
    X, y_pitch, y_vertical, y_horizontal, test_size=0.4, random_state=54)

X_val, X_test, y_pitch_val, y_pitch_test, y_vertical_val, y_vertical_test, y_horizontal_val, y_horizontal_test = train_test_split(
    X_temp, y_pitch_temp, y_vertical_temp, y_horizontal_temp, test_size=0.5, random_state=42)

num_pitches = y_pitch.shape[1]
num_vertical_locs = y_vertical.shape[1]
num_horizontal_locs = y_horizontal.shape[1]

# %% [markdown]
# ## Develop a model that does better than the baseline

# %% [markdown]
# The first step in the process is to develop a basic model that beats the baseline. This model will be a ensemble of LSTMs with 1 hidden layer with 128 units.

# %% [markdown]
# To streamline the process, two new functions will be developed:
# - `build_network`: which builds a single LSTM network with the specified parameters and compiles it.
# - `build_model`: which builds an ensemble of LSTM networks. This function will be used by Keras Tuner to optimize the hyperparameters of the model.

# %%
def build_network(input_layer, num_targets, name='', num_hidden_units=256, num_lstm_layers=2, num_dense_layers=2, activation='relu', reg=None, dropout=None):
    # Hidden LSTM layers
    x = input_layer
    for i in range(num_lstm_layers):
        layer_name = f"{name}_hidden_{i+1}"
        if reg:
            x = tf.keras.layers.LSTM(units=num_hidden_units, return_sequences=True, kernel_regularizer=reg, name=layer_name)(x)
        else:
            x = tf.keras.layers.LSTM(units=num_hidden_units, return_sequences=True, name=layer_name)(x)
        if dropout:
            x = tf.keras.layers.Dropout(dropout, name=f"{layer_name}_dropout")(x)
    
    # Attention layer
    attention_output = tf.keras.layers.Attention(name=f"{name}_attention")([x, x])
    
    # Flatten the output
    x = tf.keras.layers.Flatten(name=f"{name}_flatten")(attention_output)
    
    # Dense layers
    for i in range(num_dense_layers):
        x = tf.keras.layers.Dense(32, activation=activation, name=f"{name}_dense_{i+1}")(x)
    
    # Output layer
    outputs = tf.keras.layers.Dense(units=num_targets, activation='softmax', name=f'{name}_output')(x)

    return outputs

# %% [markdown]
# It is important to define the search space for the hyperparameters. The following hyperparameters will be optimized:
#
# - **Number of units in the hidden layer**: This will be chosen from the values [128, 256, 512].
# - **Number of hidden layers**: This will be an integer value between 1 and 3.
# - **Number of dense layers**: This will be an integer value between 1 and 3.
# - **Activation function**: This will be chosen from the values ['relu', 'elu', 'tanh', 'sigmoid'].
# - **Recurrent activation function**: This will be chosen from the values ['relu', 'elu', 'sigmoid', 'tanh'].

# %%
def build_model(hp):
    # Define the input layer
    input_layer = tf.keras.Input(shape=(X_train.shape[1], X_train.shape[2]))
    
    pitch_output = build_network(input_layer, num_targets=num_pitches, name='pitch',
                         num_hidden_units=hp.Choice('num_hidden_units', values=[128, 256, 512]),
                         num_lstm_layers=hp.Int('num_lstm_layers', min_value=1, max_value=3, step=1),
                         num_dense_layers=hp.Int('num_dense_layers', min_value=1, max_value=3, step=1),
                         activation=hp.Choice('activation', values=['relu', 'elu', 'tanh', 'sigmoid']),
                         reg=None,
                         dropout=None)
    
    vertical_output = build_network(input_layer, num_targets=num_vertical_locs, name='vertical',
                          num_hidden_units=hp.Choice('num_hidden_units', values=[128, 256, 512]),
                          num_lstm_layers=hp.Int('num_lstm_layers', min_value=1, max_value=3, step=1),
                          num_dense_layers=hp.Int('num_dense_layers', min_value=1, max_value=3, step=1),
                          activation=hp.Choice('activation', values=['relu', 'tanh', 'sigmoid']),
                          reg=None,
                          dropout=None)
    
    horizontal_output = build_network(input_layer, num_targets=num_horizontal_locs, name='horizontal',
                            num_hidden_units=hp.Choice('num_hidden_units', values=[128, 256, 512]),
                            num_lstm_layers=hp.Int('num_lstm_layers', min_value=1, max_value=3, step=1),
                            num_dense_layers=hp.Int('num_dense_layers', min_value=1, max_value=3, step=1),
                            activation=hp.Choice('activation', values=['relu', 'tanh', 'sigmoid']),
                            reg=None,
                            dropout=None)

    # Combine the models
    ensemble_model = tf.keras.models.Model(inputs=input_layer, outputs=[pitch_output, vertical_output, horizontal_output])
    # Compile the model
    ensemble_model.compile(optimizer='adam',
                      loss={'pitch_output': 'categorical_crossentropy',
                            'vertical_output': 'categorical_crossentropy',
                            'horizontal_output': 'categorical_crossentropy'},
                      metrics=['accuracy', 'accuracy', 'accuracy'])
    return ensemble_model

# %% [markdown]
# To avoid wasting time and computational resources, we will implement the FreezeOutputCallback class. This class will be used to freeze specific networks in the ensemble if their validation accuracy is worsening. If all networks in the ensemble are frozen, the training will be stopped.

# %%
from utils.callbacks import FreezeOutputCallback

freeze_output_callback = FreezeOutputCallback(patience=5)

# %%
# Create an instance of the HyperParameters object
hp = keras_tuner.HyperParameters()

# Test the build_model function
model = build_model(hp)

# Train the model
history = model.fit(X_train, 
                             {'pitch_output': y_pitch_train,
                              'vertical_output': y_vertical_train,
                              'horizontal_output': y_horizontal_train},
                             epochs=100, batch_size=64, 
                             validation_data=(X_val, 
                                              {'pitch_output': y_pitch_val,
                                               'vertical_output': y_vertical_val,
                                               'horizontal_output': y_horizontal_val}),
                             callbacks=[freeze_output_callback],
                             verbose=0
                            )
# Out:
# Freezing output vertical at 8 epochs.
#
# Freezing output horizontal at 43 epochs.
#
# Freezing output pitch at 61 epochs.
#
# All outputs frozen. Stopping training at epoch 61.

# %%
test_loss, pitch_accuracy, vertical_accuracy, horizontal_accuracy = model.evaluate(X_test, 
                                                                            {'pitch_output': y_pitch_test,
                                                                             'vertical_output': y_vertical_test,
                                                                             'horizontal_output': y_horizontal_test})
print(f"Pitch Test Accuracy: {pitch_accuracy}")
print(f"Vertical Test Accuracy: {vertical_accuracy}")
print(f"Horizontal Test Accuracy: {horizontal_accuracy}")
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - horizontal_output_accuracy: 0.6724 - loss: 5.1192 - pitch_output_accuracy: 0.6223 - vertical_output_accuracy: 0.6937
# Pitch Test Accuracy: 0.6809298992156982
# Vertical Test Accuracy: 0.6091644167900085
# Horizontal Test Accuracy: 0.6997978687286377

# %% [markdown]
# We can notice a considerable improvement in the model performance.

# %%
from utils.plot_utils import plot_ensemble_history

plot_ensemble_history(history)

# %% [markdown]
# ## Scale up

# %% [markdown]
# Now, it is time to scale up the model to increase its performance. For this, we will run Bayesian optimization using the `BayesianOptimization` class from the Keras Tuner library. The search space will be the one defined earlier. The optimization will be carried out for 10 iterations.

# %%
tuner = keras_tuner.BayesianOptimization(
    build_model,
    objective=[keras_tuner.Objective('val_vertical_output_accuracy', direction='max'),
               keras_tuner.Objective('val_horizontal_output_accuracy', direction='max'),
               keras_tuner.Objective('val_pitch_output_accuracy', direction='max')],
    max_trials=10,
    project_name='Attention_LSTM_Ensemble'
)

tuner.search(X_train, 
             {'pitch_output': y_pitch_train,
              'vertical_output': y_vertical_train,
              'horizontal_output': y_horizontal_train},
             epochs=100, batch_size=64, 
             validation_data=(X_val, 
                              {'pitch_output': y_pitch_val,
                               'vertical_output': y_vertical_val,
                               'horizontal_output': y_horizontal_val}),
             callbacks=[freeze_output_callback],
            )
# Out:
# Trial 10 Complete [00h 55m 24s]
# multi_objective: -1.8756738305091858
#
# Best multi_objective So Far: -1.9177896976470947
# Total elapsed time: 02h 56m 01s

# %%
import pandas as pd

# Get the tuner results
tuner_results = tuner.oracle.get_best_trials(num_trials=10)

# Extract relevant information
results = []
for trial in tuner_results:
    trial_summary = {
        'Trial ID': trial.trial_id,
        'Hidden layers': trial.hyperparameters.values['num_lstm_layers'],
        'Hidden units': trial.hyperparameters.values['num_hidden_units'],
        'Dense layers': trial.hyperparameters.values['num_dense_layers'],
        'Activation': trial.hyperparameters.values['activation'],
        'Score': trial.score,
        'Pitch Accuracy': trial.metrics.get_last_value('val_pitch_output_accuracy'),
        'Vertical Accuracy': trial.metrics.get_last_value('val_vertical_output_accuracy'),
        'Horizontal Accuracy': trial.metrics.get_last_value('val_horizontal_output_accuracy')
    }
    results.append(trial_summary)

# Create a DataFrame
results_df = pd.DataFrame(results)
results_df.to_csv('lstm_search_results.csv', index=False)

# Display the results
results_df
# Out:
#   Trial ID  Hidden layers  Hidden units  Dense layers Activation     Score  \
# 0       05              3           128             1    sigmoid -1.917790
# 1       03              1           256             1    sigmoid -1.907682
# 2       07              1           128             1    sigmoid -1.896900
# 3       06              3           128             2       relu -1.890836
# 4       01              2           256             2        elu -1.887129
# 5       04              1           256             2       tanh -1.883086
# 6       09              3           512             2       relu -1.875674
# 7       00              3           512             1       tanh -1.861860
# 8       02              2           512             3       relu -1.801887
# 9       08              2           512             3    sigmoid -1.596024
#
#    Pitch Accuracy  Vertical Accuracy  Horizontal Accuracy
# 0        0.594340           0.681941             0.641509
# 1        0.587938           0.673181             0.646563
# 2        0.575809           0.675202             0.645889
# 3        0.586927           0.670822             0.633086
# 4        0.612197           0.631065             0.643868
# 5        0.584232           0.655997             0.642857
# 6        0.603100           0.664420             0.608154
# 7        0.592992           0.653302             0.615566
# 8        0.563342           0.635445             0.603100
# 9        0.396226           0.616914             0.582884

# %% [markdown]
# We notice that the models with most hidden units performed worse than simpler models. This is probably due to the fact that the models with more hidden units are more prone to overfitting. Notably, models with sigmoid activations had the best performance overall.
#
# Trial 05 was the best performing model and will be used for the next steps.

# %% [markdown]
# ## Regularizing the model

# %%
def build_model():
    # Define the input layer
    input_layer = tf.keras.Input(shape=(X_train.shape[1], X_train.shape[2]))
    
    pitch_output = build_network(input_layer, num_targets=num_pitches, name='pitch',
                         num_hidden_units=128,
                         num_lstm_layers=3,
                         num_dense_layers=1,
                         activation='sigmoid',
                         reg=None,
                         dropout=None)
    
    vertical_output = build_network(input_layer, num_targets=num_vertical_locs, name='vertical',
                          num_hidden_units=128,
                          num_lstm_layers=3,
                          num_dense_layers=1,
                          activation='sigmoid',
                          reg=None,
                          dropout=None)
    
    horizontal_output = build_network(input_layer, num_targets=num_horizontal_locs, name='horizontal',
                            num_hidden_units=128,
                            num_lstm_layers=3,
                            num_dense_layers=1,
                            activation='sigmoid',
                            reg=None,
                            dropout=None)

    # Combine the models
    ensemble_model = tf.keras.models.Model(inputs=input_layer, outputs=[pitch_output, vertical_output, horizontal_output])
    # Compile the model
    ensemble_model.compile(optimizer='adam',
                      loss={'pitch_output': 'categorical_crossentropy',
                            'vertical_output': 'categorical_crossentropy',
                            'horizontal_output': 'categorical_crossentropy'},
                      metrics=['accuracy', 'accuracy', 'accuracy'])
    return ensemble_model

# %%
freeze_output_callback = FreezeOutputCallback(patience=10)

model = build_model()
history = model.fit(X_train, 
                             {'pitch_output': y_pitch_train,
                              'vertical_output': y_vertical_train,
                              'horizontal_output': y_horizontal_train},
                             epochs=100, batch_size=64, 
                             validation_data=(X_val, 
                                              {'pitch_output': y_pitch_val,
                                               'vertical_output': y_vertical_val,
                                               'horizontal_output': y_horizontal_val}),
                             callbacks=[freeze_output_callback],
                             verbose=1
                            )
# Out:
# Epoch 1/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 22s 40ms/step - horizontal_output_accuracy: 0.4381 - loss: 3.5207 - pitch_output_accuracy: 0.3315 - vertical_output_accuracy: 0.5664 - val_horizontal_output_accuracy: 0.5253 - val_loss: 3.2847 - val_pitch_output_accuracy: 0.3962 - val_vertical_output_accuracy: 0.6169
# Epoch 2/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - horizontal_output_accuracy: 0.5265 - loss: 3.2980 - pitch_output_accuracy: 0.4071 - vertical_output_accuracy: 0.6094 - val_horizontal_output_accuracy: 0.5384 - val_loss: 3.2678 - val_pitch_output_accuracy: 0.3962 - val_vertical_output_accuracy: 0.6169
# Epoch 3/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - horizontal_output_accuracy: 0.5343 - loss: 3.2758 - pitch_output_accuracy: 0.4071 - vertical_output_accuracy: 0.6103 - val_horizontal_output_accuracy: 0.5421 - val_loss: 3.2643 - val_pitch_output_accuracy: 0.3962 - val_vertical_output_accuracy: 0.6176
# Epoch 4/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - horizontal_output_accuracy: 0.5423 - loss: 3.2602 - pitch_output_accuracy: 0.4061 - vertical_output_accuracy: 0.6121 - val_horizontal_output_accuracy: 0.5482 - val_loss: 3.2441 - val_pitch_output_accuracy: 0.3962 - val_vertical_output_accuracy: 0.6196
# Epoch 5/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.5464 - loss: 3.2299 - pitch_output_accuracy: 0.4076 - vertical_output_accuracy: 0.6138 - val_horizontal_output_accuracy: 0.5458 - val_loss: 3.2339 - val_pitch_output_accuracy: 0.3962 - val_vertical_output_accuracy: 0.6193
# Epoch 6/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.5500 - loss: 3.2090 - pitch_output_accuracy: 0.4059 - vertical_output_accuracy: 0.6134 - val_horizontal_output_accuracy: 0.5428 - val_loss: 3.2321 - val_pitch_output_accuracy: 0.3962 - val_vertical_output_accuracy: 0.6183
# Epoch 7/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.5562 - loss: 3.1905 - pitch_output_accuracy: 0.4165 - vertical_output_accuracy: 0.6154 - val_horizontal_output_accuracy: 0.5404 - val_loss: 3.2332 - val_pitch_output_accuracy: 0.3962 - val_vertical_output_accuracy: 0.6196
# Epoch 8/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.5612 - loss: 3.1694 - pitch_output_accuracy: 0.4123 - vertical_output_accuracy: 0.6162 - val_horizontal_output_accuracy: 0.5458 - val_loss: 3.2299 - val_pitch_output_accuracy: 0.3939 - val_vertical_output_accuracy: 0.6196
# Epoch 9/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - horizontal_output_accuracy: 0.5668 - loss: 3.1431 - pitch_output_accuracy: 0.4158 - vertical_output_accuracy: 0.6173 - val_horizontal_output_accuracy: 0.5485 - val_loss: 3.2273 - val_pitch_output_accuracy: 0.4269 - val_vertical_output_accuracy: 0.6203
# Epoch 10/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - horizontal_output_accuracy: 0.5750 - loss: 3.1038 - pitch_output_accuracy: 0.4314 - vertical_output_accuracy: 0.6203 - val_horizontal_output_accuracy: 0.5532 - val_loss: 3.1966 - val_pitch_output_accuracy: 0.4316 - val_vertical_output_accuracy: 0.6179
# Epoch 11/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - horizontal_output_accuracy: 0.5893 - loss: 3.0415 - pitch_output_accuracy: 0.4447 - vertical_output_accuracy: 0.6275 - val_horizontal_output_accuracy: 0.5586 - val_loss: 3.1781 - val_pitch_output_accuracy: 0.4431 - val_vertical_output_accuracy: 0.6162
# Epoch 12/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - horizontal_output_accuracy: 0.5973 - loss: 2.9906 - pitch_output_accuracy: 0.4555 - vertical_output_accuracy: 0.6340 - val_horizontal_output_accuracy: 0.5559 - val_loss: 3.1727 - val_pitch_output_accuracy: 0.4444 - val_vertical_output_accuracy: 0.6162
# Epoch 13/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.6088 - loss: 2.9391 - pitch_output_accuracy: 0.4686 - vertical_output_accuracy: 0.6418 - val_horizontal_output_accuracy: 0.5583 - val_loss: 3.1563 - val_pitch_output_accuracy: 0.4599 - val_vertical_output_accuracy: 0.6146
# Epoch 14/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - horizontal_output_accuracy: 0.6200 - loss: 2.8766 - pitch_output_accuracy: 0.4813 - vertical_output_accuracy: 0.6519 - val_horizontal_output_accuracy: 0.5701 - val_loss: 3.1256 - val_pitch_output_accuracy: 0.4639 - val_vertical_output_accuracy: 0.6173
# Epoch 15/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.6357 - loss: 2.8139 - pitch_output_accuracy: 0.4921 - vertical_output_accuracy: 0.6595 - val_horizontal_output_accuracy: 0.5738 - val_loss: 3.1176 - val_pitch_output_accuracy: 0.4710 - val_vertical_output_accuracy: 0.6169
# Epoch 16/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.6432 - loss: 2.7476 - pitch_output_accuracy: 0.5026 - vertical_output_accuracy: 0.6696 - val_horizontal_output_accuracy: 0.5782 - val_loss: 3.1290 - val_pitch_output_accuracy: 0.4751 - val_vertical_output_accuracy: 0.6247
# Epoch 17/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.6491 - loss: 2.6767 - pitch_output_accuracy: 0.5114 - vertical_output_accuracy: 0.6865 - val_horizontal_output_accuracy: 0.5735 - val_loss: 3.1207 - val_pitch_output_accuracy: 0.4734 - val_vertical_output_accuracy: 0.6240
# Epoch 18/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.6527 - loss: 2.6397 - pitch_output_accuracy: 0.5161 - vertical_output_accuracy: 0.6881 - val_horizontal_output_accuracy: 0.5825 - val_loss: 3.0701 - val_pitch_output_accuracy: 0.4855 - val_vertical_output_accuracy: 0.6297
# Epoch 19/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.6646 - loss: 2.5761 - pitch_output_accuracy: 0.5328 - vertical_output_accuracy: 0.6946 - val_horizontal_output_accuracy: 0.5829 - val_loss: 3.0679 - val_pitch_output_accuracy: 0.4862 - val_vertical_output_accuracy: 0.6294
# Epoch 20/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.6773 - loss: 2.5119 - pitch_output_accuracy: 0.5343 - vertical_output_accuracy: 0.7120 - val_horizontal_output_accuracy: 0.5842 - val_loss: 3.0695 - val_pitch_output_accuracy: 0.4919 - val_vertical_output_accuracy: 0.6280
# Epoch 21/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.6815 - loss: 2.4511 - pitch_output_accuracy: 0.5440 - vertical_output_accuracy: 0.7210 - val_horizontal_output_accuracy: 0.5974 - val_loss: 3.0579 - val_pitch_output_accuracy: 0.4919 - val_vertical_output_accuracy: 0.6321
# Epoch 22/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.6924 - loss: 2.3812 - pitch_output_accuracy: 0.5598 - vertical_output_accuracy: 0.7315 - val_horizontal_output_accuracy: 0.6007 - val_loss: 3.0964 - val_pitch_output_accuracy: 0.4815 - val_vertical_output_accuracy: 0.6314
# Epoch 23/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.6984 - loss: 2.3308 - pitch_output_accuracy: 0.5762 - vertical_output_accuracy: 0.7365 - val_horizontal_output_accuracy: 0.6014 - val_loss: 3.1135 - val_pitch_output_accuracy: 0.4875 - val_vertical_output_accuracy: 0.6125
# Epoch 24/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.7115 - loss: 2.2690 - pitch_output_accuracy: 0.5804 - vertical_output_accuracy: 0.7473 - val_horizontal_output_accuracy: 0.6011 - val_loss: 3.1038 - val_pitch_output_accuracy: 0.4949 - val_vertical_output_accuracy: 0.6210
# Epoch 25/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.7270 - loss: 2.1929 - pitch_output_accuracy: 0.5916 - vertical_output_accuracy: 0.7585 - val_horizontal_output_accuracy: 0.6075 - val_loss: 3.1337 - val_pitch_output_accuracy: 0.4987 - val_vertical_output_accuracy: 0.6210
# Epoch 26/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.7323 - loss: 2.1118 - pitch_output_accuracy: 0.5964 - vertical_output_accuracy: 0.7686 - val_horizontal_output_accuracy: 0.6166 - val_loss: 3.1773 - val_pitch_output_accuracy: 0.5017 - val_vertical_output_accuracy: 0.6210
# Epoch 27/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.7492 - loss: 2.0174 - pitch_output_accuracy: 0.6171 - vertical_output_accuracy: 0.7795 - val_horizontal_output_accuracy: 0.6095 - val_loss: 3.2043 - val_pitch_output_accuracy: 0.5084 - val_vertical_output_accuracy: 0.6226
# Epoch 28/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.7614 - loss: 1.9354 - pitch_output_accuracy: 0.6332 - vertical_output_accuracy: 0.7878 - val_horizontal_output_accuracy: 0.6159 - val_loss: 3.1951 - val_pitch_output_accuracy: 0.5199 - val_vertical_output_accuracy: 0.6263
# Epoch 29/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.7742 - loss: 1.8557 - pitch_output_accuracy: 0.6538 - vertical_output_accuracy: 0.7977 - val_horizontal_output_accuracy: 0.6034 - val_loss: 3.2385 - val_pitch_output_accuracy: 0.5212 - val_vertical_output_accuracy: 0.6425
# Epoch 30/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.7836 - loss: 1.7701 - pitch_output_accuracy: 0.6627 - vertical_output_accuracy: 0.8093 - val_horizontal_output_accuracy: 0.6196 - val_loss: 3.2937 - val_pitch_output_accuracy: 0.5202 - val_vertical_output_accuracy: 0.6348
# Epoch 31/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.7839 - loss: 1.7142 - pitch_output_accuracy: 0.6720 - vertical_output_accuracy: 0.8262 - val_horizontal_output_accuracy: 0.6135 - val_loss: 3.3301 - val_pitch_output_accuracy: 0.5172 - val_vertical_output_accuracy: 0.6371
# Epoch 32/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.7908 - loss: 1.6387 - pitch_output_accuracy: 0.6965 - vertical_output_accuracy: 0.8364 - val_horizontal_output_accuracy: 0.6210 - val_loss: 3.4046 - val_pitch_output_accuracy: 0.5232 - val_vertical_output_accuracy: 0.6321
# Epoch 33/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.8126 - loss: 1.5419 - pitch_output_accuracy: 0.7123 - vertical_output_accuracy: 0.8407 - val_horizontal_output_accuracy: 0.6257 - val_loss: 3.4416 - val_pitch_output_accuracy: 0.5152 - val_vertical_output_accuracy: 0.6418
# Epoch 34/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.8182 - loss: 1.4770 - pitch_output_accuracy: 0.7310 - vertical_output_accuracy: 0.8468 - val_horizontal_output_accuracy: 0.6193 - val_loss: 3.4521 - val_pitch_output_accuracy: 0.5135 - val_vertical_output_accuracy: 0.6442
# Epoch 35/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.8309 - loss: 1.3830 - pitch_output_accuracy: 0.7506 - vertical_output_accuracy: 0.8609 - val_horizontal_output_accuracy: 0.6220 - val_loss: 3.5317 - val_pitch_output_accuracy: 0.5256 - val_vertical_output_accuracy: 0.6489
# Epoch 36/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.8389 - loss: 1.3186 - pitch_output_accuracy: 0.7597 - vertical_output_accuracy: 0.8611 - val_horizontal_output_accuracy: 0.6274 - val_loss: 3.6496 - val_pitch_output_accuracy: 0.5253 - val_vertical_output_accuracy: 0.6442
# Epoch 37/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.8433 - loss: 1.2881 - pitch_output_accuracy: 0.7755 - vertical_output_accuracy: 0.8600 - val_horizontal_output_accuracy: 0.6287 - val_loss: 3.6184 - val_pitch_output_accuracy: 0.5317 - val_vertical_output_accuracy: 0.6425
# Epoch 38/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.8573 - loss: 1.1889 - pitch_output_accuracy: 0.7841 - vertical_output_accuracy: 0.8737 - val_horizontal_output_accuracy: 0.6331 - val_loss: 3.6578 - val_pitch_output_accuracy: 0.5529 - val_vertical_output_accuracy: 0.6479
# Epoch 39/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.8603 - loss: 1.1257 - pitch_output_accuracy: 0.8044 - vertical_output_accuracy: 0.8793 - val_horizontal_output_accuracy: 0.6344 - val_loss: 3.7916 - val_pitch_output_accuracy: 0.5502 - val_vertical_output_accuracy: 0.6354
# Epoch 40/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.8674 - loss: 1.0648 - pitch_output_accuracy: 0.8145 - vertical_output_accuracy: 0.8880 - val_horizontal_output_accuracy: 0.6280 - val_loss: 3.8483 - val_pitch_output_accuracy: 0.5438 - val_vertical_output_accuracy: 0.6496
# Epoch 41/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.8769 - loss: 0.9940 - pitch_output_accuracy: 0.8220 - vertical_output_accuracy: 0.8959 - val_horizontal_output_accuracy: 0.6230 - val_loss: 3.8849 - val_pitch_output_accuracy: 0.5573 - val_vertical_output_accuracy: 0.6520
# Epoch 42/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.8745 - loss: 0.9911 - pitch_output_accuracy: 0.8348 - vertical_output_accuracy: 0.8997 - val_horizontal_output_accuracy: 0.6493 - val_loss: 3.8187 - val_pitch_output_accuracy: 0.5586 - val_vertical_output_accuracy: 0.6617
# Epoch 43/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.8816 - loss: 0.9420 - pitch_output_accuracy: 0.8474 - vertical_output_accuracy: 0.8986 - val_horizontal_output_accuracy: 0.6435 - val_loss: 3.8730 - val_pitch_output_accuracy: 0.5647 - val_vertical_output_accuracy: 0.6476
# Epoch 44/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.8918 - loss: 0.8626 - pitch_output_accuracy: 0.8606 - vertical_output_accuracy: 0.9080 - val_horizontal_output_accuracy: 0.6375 - val_loss: 4.0402 - val_pitch_output_accuracy: 0.5448 - val_vertical_output_accuracy: 0.6654
# Epoch 45/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.8976 - loss: 0.8242 - pitch_output_accuracy: 0.8719 - vertical_output_accuracy: 0.9164 - val_horizontal_output_accuracy: 0.6402 - val_loss: 4.0701 - val_pitch_output_accuracy: 0.5458 - val_vertical_output_accuracy: 0.6604
# Epoch 46/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9023 - loss: 0.8031 - pitch_output_accuracy: 0.8765 - vertical_output_accuracy: 0.9129 - val_horizontal_output_accuracy: 0.6449 - val_loss: 4.1487 - val_pitch_output_accuracy: 0.5499 - val_vertical_output_accuracy: 0.6668
# Epoch 47/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - horizontal_output_accuracy: 0.9029 - loss: 0.7584 - pitch_output_accuracy: 0.8810 - vertical_output_accuracy: 0.9112 - val_horizontal_output_accuracy: 0.6456 - val_loss: 4.2518 - val_pitch_output_accuracy: 0.5583 - val_vertical_output_accuracy: 0.6546
# Epoch 48/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - horizontal_output_accuracy: 0.9035 - loss: 0.7209 - pitch_output_accuracy: 0.8942 - vertical_output_accuracy: 0.9224 - val_horizontal_output_accuracy: 0.6469 - val_loss: 4.3672 - val_pitch_output_accuracy: 0.5401 - val_vertical_output_accuracy: 0.6631
# Epoch 49/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9151 - loss: 0.6709 - pitch_output_accuracy: 0.9001 - vertical_output_accuracy: 0.9225 - val_horizontal_output_accuracy: 0.6348 - val_loss: 4.3897 - val_pitch_output_accuracy: 0.5536 - val_vertical_output_accuracy: 0.6577
# Epoch 50/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9165 - loss: 0.6508 - pitch_output_accuracy: 0.9015 - vertical_output_accuracy: 0.9255 - val_horizontal_output_accuracy: 0.6378 - val_loss: 4.4542 - val_pitch_output_accuracy: 0.5630 - val_vertical_output_accuracy: 0.6604
# Epoch 51/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9217 - loss: 0.6396 - pitch_output_accuracy: 0.9091 - vertical_output_accuracy: 0.9143 - val_horizontal_output_accuracy: 0.6429 - val_loss: 4.4763 - val_pitch_output_accuracy: 0.5697 - val_vertical_output_accuracy: 0.6651
# Epoch 52/100
# 139/140 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - horizontal_output_accuracy: 0.9219 - loss: 0.6225 - pitch_output_accuracy: 0.9090 - vertical_output_accuracy: 0.9245
# Freezing output horizontal at 52 epochs.
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9219 - loss: 0.6224 - pitch_output_accuracy: 0.9090 - vertical_output_accuracy: 0.9245 - val_horizontal_output_accuracy: 0.6408 - val_loss: 4.4784 - val_pitch_output_accuracy: 0.5809 - val_vertical_output_accuracy: 0.6671
# Epoch 53/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9230 - loss: 0.5999 - pitch_output_accuracy: 0.9143 - vertical_output_accuracy: 0.9249 - val_horizontal_output_accuracy: 0.6402 - val_loss: 4.6121 - val_pitch_output_accuracy: 0.5684 - val_vertical_output_accuracy: 0.6725
# Epoch 54/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9244 - loss: 0.6140 - pitch_output_accuracy: 0.9060 - vertical_output_accuracy: 0.9274 - val_horizontal_output_accuracy: 0.6476 - val_loss: 4.6460 - val_pitch_output_accuracy: 0.5623 - val_vertical_output_accuracy: 0.6664
# Epoch 55/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9242 - loss: 0.5813 - pitch_output_accuracy: 0.9152 - vertical_output_accuracy: 0.9310 - val_horizontal_output_accuracy: 0.6412 - val_loss: 4.7346 - val_pitch_output_accuracy: 0.5660 - val_vertical_output_accuracy: 0.6675
# Epoch 56/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - horizontal_output_accuracy: 0.9100 - loss: 0.6159 - pitch_output_accuracy: 0.9153 - vertical_output_accuracy: 0.9380 - val_horizontal_output_accuracy: 0.6432 - val_loss: 4.6219 - val_pitch_output_accuracy: 0.5627 - val_vertical_output_accuracy: 0.6685
# Epoch 57/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9343 - loss: 0.5299 - pitch_output_accuracy: 0.9170 - vertical_output_accuracy: 0.9375 - val_horizontal_output_accuracy: 0.6594 - val_loss: 4.7318 - val_pitch_output_accuracy: 0.5660 - val_vertical_output_accuracy: 0.6695
# Epoch 58/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9146 - loss: 0.6020 - pitch_output_accuracy: 0.9123 - vertical_output_accuracy: 0.9388 - val_horizontal_output_accuracy: 0.6489 - val_loss: 4.7233 - val_pitch_output_accuracy: 0.5637 - val_vertical_output_accuracy: 0.6691
# Epoch 59/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9350 - loss: 0.5072 - pitch_output_accuracy: 0.9226 - vertical_output_accuracy: 0.9406 - val_horizontal_output_accuracy: 0.6516 - val_loss: 4.8044 - val_pitch_output_accuracy: 0.5691 - val_vertical_output_accuracy: 0.6671
# Epoch 60/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9368 - loss: 0.5172 - pitch_output_accuracy: 0.9246 - vertical_output_accuracy: 0.9309 - val_horizontal_output_accuracy: 0.6536 - val_loss: 4.7810 - val_pitch_output_accuracy: 0.5721 - val_vertical_output_accuracy: 0.6648
# Epoch 61/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9371 - loss: 0.5029 - pitch_output_accuracy: 0.9257 - vertical_output_accuracy: 0.9323 - val_horizontal_output_accuracy: 0.6472 - val_loss: 4.7964 - val_pitch_output_accuracy: 0.5704 - val_vertical_output_accuracy: 0.6728
# Epoch 62/100
# 139/140 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - horizontal_output_accuracy: 0.9315 - loss: 0.4977 - pitch_output_accuracy: 0.9269 - vertical_output_accuracy: 0.9439
# Freezing output pitch at 62 epochs.
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9315 - loss: 0.4976 - pitch_output_accuracy: 0.9269 - vertical_output_accuracy: 0.9438 - val_horizontal_output_accuracy: 0.6560 - val_loss: 4.7684 - val_pitch_output_accuracy: 0.5687 - val_vertical_output_accuracy: 0.6769
# Epoch 63/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9382 - loss: 0.4575 - pitch_output_accuracy: 0.9313 - vertical_output_accuracy: 0.9449 - val_horizontal_output_accuracy: 0.6570 - val_loss: 4.8941 - val_pitch_output_accuracy: 0.5819 - val_vertical_output_accuracy: 0.6637
# Epoch 64/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9399 - loss: 0.4663 - pitch_output_accuracy: 0.9361 - vertical_output_accuracy: 0.9415 - val_horizontal_output_accuracy: 0.6445 - val_loss: 4.9445 - val_pitch_output_accuracy: 0.5839 - val_vertical_output_accuracy: 0.6718
# Epoch 65/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9371 - loss: 0.4509 - pitch_output_accuracy: 0.9347 - vertical_output_accuracy: 0.9422 - val_horizontal_output_accuracy: 0.6577 - val_loss: 4.9899 - val_pitch_output_accuracy: 0.5738 - val_vertical_output_accuracy: 0.6701
# Epoch 66/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - horizontal_output_accuracy: 0.9355 - loss: 0.4627 - pitch_output_accuracy: 0.9368 - vertical_output_accuracy: 0.9430 - val_horizontal_output_accuracy: 0.6570 - val_loss: 4.9851 - val_pitch_output_accuracy: 0.5714 - val_vertical_output_accuracy: 0.6755
# Epoch 67/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9343 - loss: 0.4492 - pitch_output_accuracy: 0.9365 - vertical_output_accuracy: 0.9478 - val_horizontal_output_accuracy: 0.6486 - val_loss: 5.0228 - val_pitch_output_accuracy: 0.5718 - val_vertical_output_accuracy: 0.6715
# Epoch 68/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9445 - loss: 0.4233 - pitch_output_accuracy: 0.9356 - vertical_output_accuracy: 0.9449 - val_horizontal_output_accuracy: 0.6506 - val_loss: 5.0573 - val_pitch_output_accuracy: 0.5741 - val_vertical_output_accuracy: 0.6765
# Epoch 69/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - horizontal_output_accuracy: 0.9398 - loss: 0.4383 - pitch_output_accuracy: 0.9350 - vertical_output_accuracy: 0.9448 - val_horizontal_output_accuracy: 0.6439 - val_loss: 5.0483 - val_pitch_output_accuracy: 0.5697 - val_vertical_output_accuracy: 0.6735
# Epoch 70/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - horizontal_output_accuracy: 0.9428 - loss: 0.4566 - pitch_output_accuracy: 0.9367 - vertical_output_accuracy: 0.9383 - val_horizontal_output_accuracy: 0.6526 - val_loss: 5.0581 - val_pitch_output_accuracy: 0.5741 - val_vertical_output_accuracy: 0.6712
# Epoch 71/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - horizontal_output_accuracy: 0.9458 - loss: 0.4083 - pitch_output_accuracy: 0.9406 - vertical_output_accuracy: 0.9461 - val_horizontal_output_accuracy: 0.6567 - val_loss: 5.0709 - val_pitch_output_accuracy: 0.5670 - val_vertical_output_accuracy: 0.6809
# Epoch 72/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - horizontal_output_accuracy: 0.9402 - loss: 0.4222 - pitch_output_accuracy: 0.9382 - vertical_output_accuracy: 0.9498 - val_horizontal_output_accuracy: 0.6563 - val_loss: 5.1162 - val_pitch_output_accuracy: 0.5640 - val_vertical_output_accuracy: 0.6752
# Epoch 73/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - horizontal_output_accuracy: 0.9489 - loss: 0.4202 - pitch_output_accuracy: 0.9311 - vertical_output_accuracy: 0.9496 - val_horizontal_output_accuracy: 0.6358 - val_loss: 5.2255 - val_pitch_output_accuracy: 0.5660 - val_vertical_output_accuracy: 0.6739
# Epoch 74/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - horizontal_output_accuracy: 0.9383 - loss: 0.4218 - pitch_output_accuracy: 0.9400 - vertical_output_accuracy: 0.9460 - val_horizontal_output_accuracy: 0.6392 - val_loss: 5.2592 - val_pitch_output_accuracy: 0.5768 - val_vertical_output_accuracy: 0.6735
# Epoch 75/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - horizontal_output_accuracy: 0.9487 - loss: 0.3863 - pitch_output_accuracy: 0.9473 - vertical_output_accuracy: 0.9510 - val_horizontal_output_accuracy: 0.6486 - val_loss: 5.2311 - val_pitch_output_accuracy: 0.5664 - val_vertical_output_accuracy: 0.6769
# Epoch 76/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - horizontal_output_accuracy: 0.9477 - loss: 0.3901 - pitch_output_accuracy: 0.9398 - vertical_output_accuracy: 0.9525 - val_horizontal_output_accuracy: 0.6553 - val_loss: 5.2867 - val_pitch_output_accuracy: 0.5738 - val_vertical_output_accuracy: 0.6698
# Epoch 77/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - horizontal_output_accuracy: 0.9509 - loss: 0.3998 - pitch_output_accuracy: 0.9402 - vertical_output_accuracy: 0.9466 - val_horizontal_output_accuracy: 0.6429 - val_loss: 5.2246 - val_pitch_output_accuracy: 0.5849 - val_vertical_output_accuracy: 0.6675
# Epoch 78/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - horizontal_output_accuracy: 0.9402 - loss: 0.3966 - pitch_output_accuracy: 0.9476 - vertical_output_accuracy: 0.9439 - val_horizontal_output_accuracy: 0.6402 - val_loss: 5.2358 - val_pitch_output_accuracy: 0.5805 - val_vertical_output_accuracy: 0.6772
# Epoch 79/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - horizontal_output_accuracy: 0.9394 - loss: 0.3999 - pitch_output_accuracy: 0.9440 - vertical_output_accuracy: 0.9527 - val_horizontal_output_accuracy: 0.6496 - val_loss: 5.1856 - val_pitch_output_accuracy: 0.5825 - val_vertical_output_accuracy: 0.6712
# Epoch 80/100
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - horizontal_output_accuracy: 0.9419 - loss: 0.3976 - pitch_output_accuracy: 0.9434 - vertical_output_accuracy: 0.9495 - val_horizontal_output_accuracy: 0.6526 - val_loss: 5.1973 - val_pitch_output_accuracy: 0.5889 - val_vertical_output_accuracy: 0.6759
# Epoch 81/100
# 139/140 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - horizontal_output_accuracy: 0.9402 - loss: 0.4002 - pitch_output_accuracy: 0.9477 - vertical_output_accuracy: 0.9503
# Freezing output vertical at 81 epochs.
#
# All outputs frozen. Stopping training at epoch 81.
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - horizontal_output_accuracy: 0.9403 - loss: 0.4001 - pitch_output_accuracy: 0.9477 - vertical_output_accuracy: 0.9503 - val_horizontal_output_accuracy: 0.6513 - val_loss: 5.2550 - val_pitch_output_accuracy: 0.5748 - val_vertical_output_accuracy: 0.6755

# %%
from utils.plot_utils import plot_ensemble_history

plot_ensemble_history(history)

# %% [markdown]
# We see no signs of overfitting in any of the networks. In fact, the validation accuracy gets stalled at around 0.6 for all outputs. We will try to regularize the model to see if we can improve the performance.

# %% [markdown]
# ### Regularization

# %%
def build_model(reg = None, drop = None):
    # Define the input layer
    input_layer = tf.keras.Input(shape=(X_train.shape[1], X_train.shape[2]))
    
    pitch_output = build_network(input_layer, num_targets=num_pitches, name='pitch',
                         num_hidden_units=128,
                         num_lstm_layers=3,
                         num_dense_layers=1,
                         activation='sigmoid',
                         reg=reg,
                         dropout=drop)
    
    vertical_output = build_network(input_layer, num_targets=num_vertical_locs, name='vertical',
                          num_hidden_units=128,
                          num_lstm_layers=3,
                          num_dense_layers=1,
                          activation='sigmoid',
                          reg=reg,
                          dropout=drop)
    
    horizontal_output = build_network(input_layer, num_targets=num_horizontal_locs, name='horizontal',
                            num_hidden_units=128,
                            num_lstm_layers=3,
                            num_dense_layers=1,
                            activation='sigmoid',
                            reg=reg,
                            dropout=drop)

    # Combine the models
    ensemble_model = tf.keras.models.Model(inputs=input_layer, outputs=[pitch_output, vertical_output, horizontal_output])
    # Compile the model
    ensemble_model.compile(optimizer='adam',
                      loss={'pitch_output': 'categorical_crossentropy',
                            'vertical_output': 'categorical_crossentropy',
                            'horizontal_output': 'categorical_crossentropy'},
                      metrics=['accuracy', 'accuracy', 'accuracy'])
    return ensemble_model

# %%
freeze_output_callback = FreezeOutputCallback(patience=10)

regularizations = [tf.keras.regularizers.l1(0.001), tf.keras.regularizers.l2(0.001), tf.keras.regularizers.l1_l2(l1=0.001, l2=0.001)]
histories = []

for reg in regularizations:
    print("Testing with regularization:", reg)
    model = build_model(reg=reg)
    history = model.fit(X_train, 
                                 {'pitch_output': y_pitch_train,
                                  'vertical_output': y_vertical_train,
                                  'horizontal_output': y_horizontal_train},
                                 epochs=100, batch_size=64, 
                                 validation_data=(X_val, 
                                                  {'pitch_output': y_pitch_val,
                                                   'vertical_output': y_vertical_val,
                                                   'horizontal_output': y_horizontal_val}),
                                 callbacks=[freeze_output_callback],
                                 verbose=0
                                )
    histories.append(history)
# Out:
# Testing with regularization: <keras.src.regularizers.regularizers.L1 object at 0x000001DF78CBF3D0>
#
# Freezing output vertical at 11 epochs.
#
# Freezing output horizontal at 11 epochs.
#
# Freezing output pitch at 35 epochs.
#
# All outputs frozen. Stopping training at epoch 35.
# Testing with regularization: <keras.src.regularizers.regularizers.L2 object at 0x000001DF78C3A9D0>
#
# Freezing output vertical at 11 epochs.
#
# Freezing output horizontal at 63 epochs.
#
# Freezing output pitch at 66 epochs.
#
# All outputs frozen. Stopping training at epoch 66.
# Testing with regularization: <keras.src.regularizers.regularizers.L1L2 object at 0x000001DF78C3AA50>
#
# Freezing output vertical at 11 epochs.
#
# Freezing output horizontal at 11 epochs.
#
# Freezing output pitch at 35 epochs.
#
# All outputs frozen. Stopping training at epoch 35.

# %%
from utils.plot_utils import smooth_curve

import matplotlib.pyplot as plt

# Smooth the curves for better visualization
smooth_l1_pitch_val = smooth_curve(histories[0].history['val_pitch_output_accuracy'])
smooth_l2_pitch_val = smooth_curve(histories[1].history['val_pitch_output_accuracy'])
smooth_l1_l2_pitch_val = smooth_curve(histories[2].history['val_pitch_output_accuracy'])

smooth_l1_pitch_train = smooth_curve(histories[0].history['pitch_output_accuracy'])
smooth_l2_pitch_train = smooth_curve(histories[1].history['pitch_output_accuracy'])
smooth_l1_l2_pitch_train = smooth_curve(histories[2].history['pitch_output_accuracy'])

smooth_l1_vertical_val = smooth_curve(histories[0].history['val_vertical_output_accuracy'])
smooth_l2_vertical_val = smooth_curve(histories[1].history['val_vertical_output_accuracy'])
smooth_l1_l2_vertical_val = smooth_curve(histories[2].history['val_vertical_output_accuracy'])

smooth_l1_vertical_train = smooth_curve(histories[0].history['vertical_output_accuracy'])
smooth_l2_vertical_train = smooth_curve(histories[1].history['vertical_output_accuracy'])
smooth_l1_l2_vertical_train = smooth_curve(histories[2].history['vertical_output_accuracy'])

smooth_l1_horizontal_val = smooth_curve(histories[0].history['val_horizontal_output_accuracy'])
smooth_l2_horizontal_val = smooth_curve(histories[1].history['val_horizontal_output_accuracy'])
smooth_l1_l2_horizontal_val = smooth_curve(histories[2].history['val_horizontal_output_accuracy'])

smooth_l1_horizontal_train = smooth_curve(histories[0].history['horizontal_output_accuracy'])
smooth_l2_horizontal_train = smooth_curve(histories[1].history['horizontal_output_accuracy'])
smooth_l1_l2_horizontal_train = smooth_curve(histories[2].history['horizontal_output_accuracy'])

# Create a collage of plots
fig, axes = plt.subplots(3, 3, figsize=(18, 18))

# Plot L1 regularization
axes[0, 0].plot(range(1, len(smooth_l1_pitch_val) + 1), smooth_l1_pitch_val, label='L1 Val')
axes[0, 0].plot(range(1, len(smooth_l1_pitch_train) + 1), smooth_l1_pitch_train, label='L1 Train')
axes[0, 0].set_title('L1 Regularization - Pitch')
axes[0, 0].set_xlabel('Epochs')
axes[0, 0].set_ylabel('Accuracy')
axes[0, 0].legend()

axes[1, 0].plot(range(1, len(smooth_l1_vertical_val) + 1), smooth_l1_vertical_val, label='L1 Val')
axes[1, 0].plot(range(1, len(smooth_l1_vertical_train) + 1), smooth_l1_vertical_train, label='L1 Train')
axes[1, 0].set_title('L1 Regularization - Vertical')
axes[1, 0].set_xlabel('Epochs')
axes[1, 0].set_ylabel('Accuracy')
axes[1, 0].legend()

axes[2, 0].plot(range(1, len(smooth_l1_horizontal_val) + 1), smooth_l1_horizontal_val, label='L1 Val')
axes[2, 0].plot(range(1, len(smooth_l1_horizontal_train) + 1), smooth_l1_horizontal_train, label='L1 Train')
axes[2, 0].set_title('L1 Regularization - Horizontal')
axes[2, 0].set_xlabel('Epochs')
axes[2, 0].set_ylabel('Accuracy')
axes[2, 0].legend()

# Plot L2 regularization
axes[0, 1].plot(range(1, len(smooth_l2_pitch_val) + 1), smooth_l2_pitch_val, label='L2 Val')
axes[0, 1].plot(range(1, len(smooth_l2_pitch_train) + 1), smooth_l2_pitch_train, label='L2 Train')
axes[0, 1].set_title('L2 Regularization - Pitch')
axes[0, 1].set_xlabel('Epochs')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].legend()

axes[1, 1].plot(range(1, len(smooth_l2_vertical_val) + 1), smooth_l2_vertical_val, label='L2 Val')
axes[1, 1].plot(range(1, len(smooth_l2_vertical_train) + 1), smooth_l2_vertical_train, label='L2 Train')
axes[1, 1].set_title('L2 Regularization - Vertical')
axes[1, 1].set_xlabel('Epochs')
axes[1, 1].set_ylabel('Accuracy')
axes[1, 1].legend()

axes[2, 1].plot(range(1, len(smooth_l2_horizontal_val) + 1), smooth_l2_horizontal_val, label='L2 Val')
axes[2, 1].plot(range(1, len(smooth_l2_horizontal_train) + 1), smooth_l2_horizontal_train, label='L2 Train')
axes[2, 1].set_title('L2 Regularization - Horizontal')
axes[2, 1].set_xlabel('Epochs')
axes[2, 1].set_ylabel('Accuracy')
axes[2, 1].legend()

# Plot L1_L2 regularization
axes[0, 2].plot(range(1, len(smooth_l1_l2_pitch_val) + 1), smooth_l1_l2_pitch_val, label='L1_L2 Val')
axes[0, 2].plot(range(1, len(smooth_l1_l2_pitch_train) + 1), smooth_l1_l2_pitch_train, label='L1_L2 Train')
axes[0, 2].set_title('L1_L2 Regularization - Pitch')
axes[0, 2].set_xlabel('Epochs')
axes[0, 2].set_ylabel('Accuracy')
axes[0, 2].legend()

axes[1, 2].plot(range(1, len(smooth_l1_l2_vertical_val) + 1), smooth_l1_l2_vertical_val, label='L1_L2 Val')
axes[1, 2].plot(range(1, len(smooth_l1_l2_vertical_train) + 1), smooth_l1_l2_vertical_train, label='L1_L2 Train')
axes[1, 2].set_title('L1_L2 Regularization - Vertical')
axes[1, 2].set_xlabel('Epochs')
axes[1, 2].set_ylabel('Accuracy')
axes[1, 2].legend()

axes[2, 2].plot(range(1, len(smooth_l1_l2_horizontal_val) + 1), smooth_l1_l2_horizontal_val, label='L1_L2 Val')
axes[2, 2].plot(range(1, len(smooth_l1_l2_horizontal_train) + 1), smooth_l1_l2_horizontal_train, label='L1_L2 Train')
axes[2, 2].set_title('L1_L2 Regularization - Horizontal')
axes[2, 2].set_xlabel('Epochs')
axes[2, 2].set_ylabel('Accuracy')
axes[2, 2].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# We don't see any improvement in the model performance after applying regularization. We will stick to the model with the best performance so far.

# %% [markdown]
# ### Dropout

# %%
dropout_rates = [0, 0.5]
histories_dropout = []

for dropout_rate in dropout_rates:
    print("Testing with dropout rate:", dropout_rate)
    model = build_model(drop=dropout_rate)
    history = model.fit(X_train, 
                                 {'pitch_output': y_pitch_train,
                                  'vertical_output': y_vertical_train,
                                  'horizontal_output': y_horizontal_train},
                                 epochs=100, batch_size=64, 
                                 validation_data=(X_val, 
                                                  {'pitch_output': y_pitch_val,
                                                   'vertical_output': y_vertical_val,
                                                   'horizontal_output': y_horizontal_val}),
                                 callbacks=[freeze_output_callback],
                                 verbose=0
                                )
    histories_dropout.append(history)
# Out:
# Testing with dropout rate: 0
#
# Freezing output pitch at 11 epochs.
#
# Freezing output vertical at 19 epochs.
#
# Freezing output horizontal at 53 epochs.
#
# All outputs frozen. Stopping training at epoch 53.
# Testing with dropout rate: 0.5
#
# Freezing output vertical at 60 epochs.
#
# Freezing output horizontal at 62 epochs.

# %%
# Smooth the curves for better visualization
smooth_no_drop_pitch_val = smooth_curve(histories_dropout[0].history['val_pitch_output_accuracy'])
smooth_drop_05_pitch_val = smooth_curve(histories_dropout[1].history['val_pitch_output_accuracy'])
smooth_no_drop_pitch_train = smooth_curve(histories_dropout[0].history['pitch_output_accuracy'])
smooth_drop_05_pitch_train = smooth_curve(histories_dropout[1].history['pitch_output_accuracy'])

smooth_no_drop_vertical_val = smooth_curve(histories_dropout[0].history['val_vertical_output_accuracy'])
smooth_drop_05_vertical_val = smooth_curve(histories_dropout[1].history['val_vertical_output_accuracy'])
smooth_no_drop_vertical_train = smooth_curve(histories_dropout[0].history['vertical_output_accuracy'])
smooth_drop_05_vertical_train = smooth_curve(histories_dropout[1].history['vertical_output_accuracy'])

smooth_no_drop_horizontal_val = smooth_curve(histories_dropout[0].history['val_horizontal_output_accuracy'])
smooth_drop_05_horizontal_val = smooth_curve(histories_dropout[1].history['val_horizontal_output_accuracy'])
smooth_no_drop_horizontal_train = smooth_curve(histories_dropout[0].history['horizontal_output_accuracy'])
smooth_drop_05_horizontal_train = smooth_curve(histories_dropout[1].history['horizontal_output_accuracy'])

# Create a collage of plots
fig, axes = plt.subplots(3, 2, figsize=(12, 18))

# Plot without dropout for pitch
axes[0, 0].plot(range(1, len(smooth_no_drop_pitch_val) + 1), smooth_no_drop_pitch_val, label='No Dropout Val')
axes[0, 0].plot(range(1, len(smooth_no_drop_pitch_train) + 1), smooth_no_drop_pitch_train, label='No Dropout Train')
axes[0, 0].set_title('No Dropout - Pitch')
axes[0, 0].set_xlabel('Epochs')
axes[0, 0].set_ylabel('Accuracy')
axes[0, 0].legend()

# Plot with 0.5 dropout for pitch
axes[0, 1].plot(range(1, len(smooth_drop_05_pitch_val) + 1), smooth_drop_05_pitch_val, label='Dropout 0.5 Val')
axes[0, 1].plot(range(1, len(smooth_drop_05_pitch_train) + 1), smooth_drop_05_pitch_train, label='Dropout 0.5 Train')
axes[0, 1].set_title('Dropout 0.5 - Pitch')
axes[0, 1].set_xlabel('Epochs')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].legend()

# Plot without dropout for vertical
axes[1, 0].plot(range(1, len(smooth_no_drop_vertical_val) + 1), smooth_no_drop_vertical_val, label='No Dropout Val')
axes[1, 0].plot(range(1, len(smooth_no_drop_vertical_train) + 1), smooth_no_drop_vertical_train, label='No Dropout Train')
axes[1, 0].set_title('No Dropout - Vertical')
axes[1, 0].set_xlabel('Epochs')
axes[1, 0].set_ylabel('Accuracy')
axes[1, 0].legend()

# Plot with 0.5 dropout for vertical
axes[1, 1].plot(range(1, len(smooth_drop_05_vertical_val) + 1), smooth_drop_05_vertical_val, label='Dropout 0.5 Val')
axes[1, 1].plot(range(1, len(smooth_drop_05_vertical_train) + 1), smooth_drop_05_vertical_train, label='Dropout 0.5 Train')
axes[1, 1].set_title('Dropout 0.5 - Vertical')
axes[1, 1].set_xlabel('Epochs')
axes[1, 1].set_ylabel('Accuracy')
axes[1, 1].legend()

# Plot without dropout for horizontal
axes[2, 0].plot(range(1, len(smooth_no_drop_horizontal_val) + 1), smooth_no_drop_horizontal_val, label='No Dropout Val')
axes[2, 0].plot(range(1, len(smooth_no_drop_horizontal_train) + 1), smooth_no_drop_horizontal_train, label='No Dropout Train')
axes[2, 0].set_title('No Dropout - Horizontal')
axes[2, 0].set_xlabel('Epochs')
axes[2, 0].set_ylabel('Accuracy')
axes[2, 0].legend()

# Plot with 0.5 dropout for horizontal
axes[2, 1].plot(range(1, len(smooth_drop_05_horizontal_val) + 1), smooth_drop_05_horizontal_val, label='Dropout 0.5 Val')
axes[2, 1].plot(range(1, len(smooth_drop_05_horizontal_train) + 1), smooth_drop_05_horizontal_train, label='Dropout 0.5 Train')
axes[2, 1].set_title('Dropout 0.5 - Horizontal')
axes[2, 1].set_xlabel('Epochs')
axes[2, 1].set_ylabel('Accuracy')
axes[2, 1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# We see that the model with dropout has a better performance than the model without it.

# %% [markdown]
# ## Final Model

# %% [markdown]
# Dropout will be used for all networks. The best hyperparameters for each output will be used to build the final model.

# %%
def build_model():
    # Define the input layer
    input_layer = tf.keras.Input(shape=(X_train.shape[1], X_train.shape[2]))

    drop = 0.5
    
    pitch_output = build_network(input_layer, num_targets=num_pitches, name='pitch',
                         num_hidden_units=128,
                         num_lstm_layers=3,
                         num_dense_layers=1,
                         activation='sigmoid',
                         dropout=drop)
    
    vertical_output = build_network(input_layer, num_targets=num_vertical_locs, name='vertical',
                          num_hidden_units=128,
                          num_lstm_layers=3,
                          num_dense_layers=1,
                          activation='sigmoid',
                          dropout=drop)
    
    horizontal_output = build_network(input_layer, num_targets=num_horizontal_locs, name='horizontal',
                            num_hidden_units=128,
                            num_lstm_layers=3,
                            num_dense_layers=1,
                            activation='sigmoid',
                            dropout=drop)

    # Combine the models
    ensemble_model = tf.keras.models.Model(inputs=input_layer, outputs=[pitch_output, vertical_output, horizontal_output])
    # Compile the model
    ensemble_model.compile(optimizer='adam',
                      loss={'pitch_output': 'categorical_crossentropy',
                            'vertical_output': 'categorical_crossentropy',
                            'horizontal_output': 'categorical_crossentropy'},
                      metrics=['accuracy', 'accuracy', 'accuracy'])
    return ensemble_model

# %%
# Test the build_model function
model = build_model()

# Train the model
history = model.fit(X_train, 
                             {'pitch_output': y_pitch_train,
                              'vertical_output': y_vertical_train,
                              'horizontal_output': y_horizontal_train},
                             epochs=100, batch_size=64, 
                             validation_data=(X_val, 
                                              {'pitch_output': y_pitch_val,
                                               'vertical_output': y_vertical_val,
                                               'horizontal_output': y_horizontal_val}),
                             callbacks=[freeze_output_callback],
                             verbose=0
                            )
# Out:
# Freezing output horizontal at 57 epochs.

# %%
from utils.plot_utils import plot_ensemble_history
plot_ensemble_history(history)

# %%
max_pitch_val_accuracy = max(history.history['val_pitch_output_accuracy'])
max_vertical_val_accuracy = max(history.history['val_vertical_output_accuracy'])
max_horizontal_val_accuracy = max(history.history['val_horizontal_output_accuracy'])

print(f"Max Pitch Validation Accuracy: {max_pitch_val_accuracy}")
print(f"Max Vertical Validation Accuracy: {max_vertical_val_accuracy}")
print(f"Max Horizontal Validation Accuracy: {max_horizontal_val_accuracy}")
# Out:
# Max Pitch Validation Accuracy: 0.6179245114326477
# Max Vertical Validation Accuracy: 0.6991239786148071
# Max Horizontal Validation Accuracy: 0.671159029006958

# %% [markdown]
# We can see a considerable increase in each output's accuracy compared to the baseline. Now, it is time to test the final model in the test set.

# %%
test_loss, pitch_accuracy, vertical_accuracy, horizontal_accuracy = model.evaluate(X_test, 
                                                                            {'pitch_output': y_pitch_test,
                                                                             'vertical_output': y_vertical_test,
                                                                             'horizontal_output': y_horizontal_test})
print(f"Pitch Test Accuracy: {pitch_accuracy}")
print(f"Vertical Test Accuracy: {vertical_accuracy}")
print(f"Horizontal Test Accuracy: {horizontal_accuracy}")
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - horizontal_output_accuracy: 0.6885 - loss: 3.7867 - pitch_output_accuracy: 0.6192 - vertical_output_accuracy: 0.6843
# Pitch Test Accuracy: 0.6812668442726135
# Vertical Test Accuracy: 0.6290431022644043
# Horizontal Test Accuracy: 0.6863207817077637

# %% [markdown]
# We notice that the model performs well in the test set. The accuracy is around 0.6 for all outputs. This is a considerable improvement compared to the baseline.
